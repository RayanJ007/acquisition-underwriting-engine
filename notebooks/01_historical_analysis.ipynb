# %% [markdown]
# # Historical financial review
# Garmin historical case at 2025-02-28. This notebook uses the production modules; assumptions and sources are documented in the repository.

# %%
from pathlib import Path
import sys
root=Path.cwd().parent if Path.cwd().name=='notebooks' else Path.cwd()
sys.path.insert(0,str(root))

# %%
from src.data import load_historicals
from src.historicals import analyze, commentary
h=load_historicals()
print(commentary(h))
analyze(h)[['year','revenue','ebitda','fcf','roic','cash_conversion_cycle']]
# Out:
# Revenue compounded at 10.7%; EBITDA margin moved from 27.9% to 28.0%. The weakest revenue growth was -2.5% in 2022. Latest CFO/EBITDA was 81.2%, with 213 days in the cash conversion cycle. Inventory days moved from 163 to 207; FCF was $1,239m against EBITDA of $1,765m.
#    year   revenue    ebitda       fcf      roic  cash_conversion_cycle
# 0  2020  4186.573  1167.158   949.866       NaN             181.767644
# 1  2021  4982.795  1357.658   704.782  0.394636             211.382315
# 2  2022  4860.286  1177.149   543.973  0.287224             280.862980
# 3  2023  5228.252  1255.020  1182.741  0.314486             236.215948
# 4  2024  6296.903  1765.154  1238.900  0.328952             213.456592
